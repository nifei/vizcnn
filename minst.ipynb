# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torch.nn.functional as F
import torch.optim as optim
## load mnist dataset
use_cuda = torch.cuda.is_available()

root = './data'
if not os.path.exists(root):
    os.mkdir(root)
    
trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])
# if not exist, download mnist dataset
train_set = dset.MNIST(root=root, train=True, transform=trans, download=True)
test_set = dset.MNIST(root=root, train=False, transform=trans, download=True)

batch_size = 100

train_loader = torch.utils.data.DataLoader(
                 dataset=train_set,
                 batch_size=batch_size,
                 shuffle=True)
test_loader = torch.utils.data.DataLoader(
                dataset=test_set,
                batch_size=batch_size,
                shuffle=False)

print('==>>> total trainning batch number: {}'.format(len(train_loader)))
print('==>>> total testing batch number: {}'.format(len(test_loader)))

## network
class MLPNet(nn.Module):
    def __init__(self):
        super(MLPNet, self).__init__()
        self.fc1 = nn.Linear(28*28, 500)
        self.fc2 = nn.Linear(500, 256)
        self.fc3 = nn.Linear(256, 10)
    def forward(self, x):
        x = x.view(-1, 28*28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
    def name(self):
        return "MLP"

class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x
    
    def name(self):
        return "LeNet"
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# ==>>> total trainning batch number: 600
# ==>>> total testing batch number: 100

# %%
## training
model = LeNet()

if use_cuda:
    model = model.cuda()

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

criterion = nn.CrossEntropyLoss()

for epoch in range(10):
    # trainning
    ave_loss = 0
    for batch_idx, (x, target) in enumerate(train_loader):
        optimizer.zero_grad()
        if use_cuda:
            x, target = x.cuda(), target.cuda()
        x, target = Variable(x), Variable(target)
        out = model(x)
        loss = criterion(out, target)
        ave_loss = ave_loss * 0.9 + loss.data[0] * 0.1
        loss.backward()
        optimizer.step()
        if (batch_idx+1) % 100 == 0 or (batch_idx+1) == len(train_loader):
            print('==>>> epoch: {}, batch index: {}, train loss: {:.6f}'.format(
                epoch, batch_idx+1, ave_loss))
    # testing
    correct_cnt, ave_loss = 0, 0
    total_cnt = 0
    for batch_idx, (x, target) in enumerate(test_loader):
        if use_cuda:
            x, target = x.cuda(), target.cuda()
        x, target = Variable(x, volatile=True), Variable(target, volatile=True)
        out = model(x)
        loss = criterion(out, target)
        _, pred_label = torch.max(out.data, 1)
        total_cnt += x.data.size()[0]
        correct_cnt += (pred_label == target.data).sum()
        # smooth average
        ave_loss = ave_loss * 0.9 + loss.data[0] * 0.1
        
        if(batch_idx+1) % 100 == 0 or (batch_idx+1) == len(test_loader):
            print('==>>> epoch: {}, batch index: {}, test loss: {:.6f}, acc: {:.3f}'.format(
                epoch, batch_idx+1, ave_loss, correct_cnt * 1.0 / total_cnt))

torch.save(model.state_dict(), model.name())
# Out:
# ==>>> epoch: 0, batch index: 100, train loss: 0.625506
# ==>>> epoch: 0, batch index: 200, train loss: 0.263323
# ==>>> epoch: 0, batch index: 300, train loss: 0.175850
# ==>>> epoch: 0, batch index: 400, train loss: 0.122536
# ==>>> epoch: 0, batch index: 500, train loss: 0.097283
# ==>>> epoch: 0, batch index: 600, train loss: 0.101730
# ==>>> epoch: 0, batch index: 100, test loss: 0.059838, acc: 0.977
# ==>>> epoch: 1, batch index: 100, train loss: 0.081233
# ==>>> epoch: 1, batch index: 200, train loss: 0.071966
# ==>>> epoch: 1, batch index: 300, train loss: 0.068411
# ==>>> epoch: 1, batch index: 400, train loss: 0.059925
# ==>>> epoch: 1, batch index: 500, train loss: 0.043335
# ==>>> epoch: 1, batch index: 600, train loss: 0.044617
# ==>>> epoch: 1, batch index: 100, test loss: 0.037621, acc: 0.985
# ==>>> epoch: 2, batch index: 100, train loss: 0.048126
# ==>>> epoch: 2, batch index: 200, train loss: 0.045886
# ==>>> epoch: 2, batch index: 300, train loss: 0.035088
# ==>>> epoch: 2, batch index: 400, train loss: 0.064933
# ==>>> epoch: 2, batch index: 500, train loss: 0.059143
# ==>>> epoch: 2, batch index: 600, train loss: 0.043617
# ==>>> epoch: 2, batch index: 100, test loss: 0.025111, acc: 0.988
# ==>>> epoch: 3, batch index: 100, train loss: 0.035500
# ==>>> epoch: 3, batch index: 200, train loss: 0.030153
# ==>>> epoch: 3, batch index: 300, train loss: 0.033822
# ==>>> epoch: 3, batch index: 400, train loss: 0.040366
# ==>>> epoch: 3, batch index: 500, train loss: 0.042803
# ==>>> epoch: 3, batch index: 600, train loss: 0.030583
# ==>>> epoch: 3, batch index: 100, test loss: 0.024414, acc: 0.988
# ==>>> epoch: 4, batch index: 100, train loss: 0.031623
# ==>>> epoch: 4, batch index: 200, train loss: 0.034941
# ==>>> epoch: 4, batch index: 300, train loss: 0.032379
# ==>>> epoch: 4, batch index: 400, train loss: 0.039005
# ==>>> epoch: 4, batch index: 500, train loss: 0.023670
# ==>>> epoch: 4, batch index: 600, train loss: 0.037296
# ==>>> epoch: 4, batch index: 100, test loss: 0.024814, acc: 0.991
# ==>>> epoch: 5, batch index: 100, train loss: 0.026178
# ==>>> epoch: 5, batch index: 200, train loss: 0.022489
# ==>>> epoch: 5, batch index: 300, train loss: 0.031150
# ==>>> epoch: 5, batch index: 400, train loss: 0.021713
# ==>>> epoch: 5, batch index: 500, train loss: 0.023405
# ==>>> epoch: 5, batch index: 600, train loss: 0.025450
# ==>>> epoch: 5, batch index: 100, test loss: 0.020823, acc: 0.991
# ==>>> epoch: 6, batch index: 100, train loss: 0.019077
# ==>>> epoch: 6, batch index: 200, train loss: 0.012296
# ==>>> epoch: 6, batch index: 300, train loss: 0.020255
# ==>>> epoch: 6, batch index: 400, train loss: 0.016570
# ==>>> epoch: 6, batch index: 500, train loss: 0.020164
# ==>>> epoch: 6, batch index: 600, train loss: 0.015858
# ==>>> epoch: 6, batch index: 100, test loss: 0.016953, acc: 0.991
# ==>>> epoch: 7, batch index: 100, train loss: 0.019443
# ==>>> epoch: 7, batch index: 200, train loss: 0.021556
# ==>>> epoch: 7, batch index: 300, train loss: 0.019222
# ==>>> epoch: 7, batch index: 400, train loss: 0.015864
# ==>>> epoch: 7, batch index: 500, train loss: 0.022368
# ==>>> epoch: 7, batch index: 600, train loss: 0.022073
# ==>>> epoch: 7, batch index: 100, test loss: 0.016849, acc: 0.991
# ==>>> epoch: 8, batch index: 100, train loss: 0.020700
# ==>>> epoch: 8, batch index: 200, train loss: 0.013067
# ==>>> epoch: 8, batch index: 300, train loss: 0.015404
# ==>>> epoch: 8, batch index: 400, train loss: 0.009129
# ==>>> epoch: 8, batch index: 500, train loss: 0.011635
# ==>>> epoch: 8, batch index: 600, train loss: 0.019428
# ==>>> epoch: 8, batch index: 100, test loss: 0.015418, acc: 0.992
# ==>>> epoch: 9, batch index: 100, train loss: 0.008040
# ==>>> epoch: 9, batch index: 200, train loss: 0.012488
# ==>>> epoch: 9, batch index: 300, train loss: 0.020789
# ==>>> epoch: 9, batch index: 400, train loss: 0.015941
# ==>>> epoch: 9, batch index: 500, train loss: 0.018234
# ==>>> epoch: 9, batch index: 600, train loss: 0.011217
# ==>>> epoch: 9, batch index: 100, test loss: 0.013503, acc: 0.992

# %%
the_model = LeNet()
the_model.load_state_dict(torch.load("LeNet"))  #读取网络参数
