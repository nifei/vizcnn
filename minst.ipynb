# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch

# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torch.nn.functional as F
import torch.optim as optim
## load mnist dataset
use_cuda = torch.cuda.is_available()

root = './data'
if not os.path.exists(root):
    os.mkdir(root)
    
trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])
# if not exist, download mnist dataset
train_set = dset.MNIST(root=root, train=True, transform=trans, download=True)
test_set = dset.MNIST(root=root, train=False, transform=trans, download=True)

batch_size = 100

train_loader = torch.utils.data.DataLoader(
                 dataset=train_set,
                 batch_size=batch_size,
                 shuffle=True)
test_loader = torch.utils.data.DataLoader(
                dataset=test_set,
                batch_size=batch_size,
                shuffle=False)

print('==>>> total trainning batch number: {}'.format(len(train_loader)))
print('==>>> total testing batch number: {}'.format(len(test_loader)))

## network
class MLPNet(nn.Module):
    def __init__(self):
        super(MLPNet, self).__init__()
        self.fc1 = nn.Linear(28*28, 500)
        self.fc2 = nn.Linear(500, 256)
        self.fc3 = nn.Linear(256, 10)
    def forward(self, x):
        x = x.view(-1, 28*28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
    def name(self):
        return "MLP"

class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x
    
    def name(self):
        return "LeNet"
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# ==>>> total trainning batch number: 600
# ==>>> total testing batch number: 100

# %%
## training
model = LeNet()

if use_cuda:
    model = model.cuda()

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

criterion = nn.CrossEntropyLoss()

for epoch in range(10):
    # trainning
    ave_loss = 0
    for batch_idx, (x, target) in enumerate(train_loader):
        optimizer.zero_grad()
        if use_cuda:
            x, target = x.cuda(), target.cuda()
        x, target = Variable(x), Variable(target)
        out = model(x)
        loss = criterion(out, target)
        ave_loss = ave_loss * 0.9 + loss.data[0] * 0.1
        loss.backward()
        optimizer.step()
        if (batch_idx+1) % 100 == 0 or (batch_idx+1) == len(train_loader):
            print('==>>> epoch: {}, batch index: {}, train loss: {:.6f}'.format(
                epoch, batch_idx+1, ave_loss))
    # testing
    correct_cnt, ave_loss = 0, 0
    total_cnt = 0
    for batch_idx, (x, target) in enumerate(test_loader):
        if use_cuda:
            x, target = x.cuda(), target.cuda()
        x, target = Variable(x, volatile=True), Variable(target, volatile=True)
        out = model(x)
        loss = criterion(out, target)
        _, pred_label = torch.max(out.data, 1)
        total_cnt += x.data.size()[0]
        correct_cnt += (pred_label == target.data).sum()
        # smooth average
        ave_loss = ave_loss * 0.9 + loss.data[0] * 0.1
        
        if(batch_idx+1) % 100 == 0 or (batch_idx+1) == len(test_loader):
            print('==>>> epoch: {}, batch index: {}, test loss: {:.6f}, acc: {:.3f}'.format(
                epoch, batch_idx+1, ave_loss, correct_cnt * 1.0 / total_cnt))

torch.save(model.state_dict(), model.name())
# Out:
# ==>>> epoch: 0, batch index: 100, train loss: 0.617537
# ==>>> epoch: 0, batch index: 200, train loss: 0.223271
# ==>>> epoch: 0, batch index: 300, train loss: 0.169259
# ==>>> epoch: 0, batch index: 400, train loss: 0.132721
# ==>>> epoch: 0, batch index: 500, train loss: 0.107388
# ==>>> epoch: 0, batch index: 600, train loss: 0.107374
# ==>>> epoch: 0, batch index: 100, test loss: 0.074433, acc: 0.975
# ==>>> epoch: 1, batch index: 100, train loss: 0.091578
# ==>>> epoch: 1, batch index: 200, train loss: 0.067954
# ==>>> epoch: 1, batch index: 300, train loss: 0.071525
# ==>>> epoch: 1, batch index: 400, train loss: 0.064465
# ==>>> epoch: 1, batch index: 500, train loss: 0.088125
# ==>>> epoch: 1, batch index: 600, train loss: 0.040020
# ==>>> epoch: 1, batch index: 100, test loss: 0.035807, acc: 0.984
# ==>>> epoch: 2, batch index: 100, train loss: 0.054121
# ==>>> epoch: 2, batch index: 200, train loss: 0.057559
# ==>>> epoch: 2, batch index: 300, train loss: 0.049374
# ==>>> epoch: 2, batch index: 400, train loss: 0.056275
# ==>>> epoch: 2, batch index: 500, train loss: 0.050826
# ==>>> epoch: 2, batch index: 600, train loss: 0.061263
# ==>>> epoch: 2, batch index: 100, test loss: 0.026143, acc: 0.987
# ==>>> epoch: 3, batch index: 100, train loss: 0.034196
# ==>>> epoch: 3, batch index: 200, train loss: 0.038506
# ==>>> epoch: 3, batch index: 300, train loss: 0.048125
# ==>>> epoch: 3, batch index: 400, train loss: 0.037226
# ==>>> epoch: 3, batch index: 500, train loss: 0.032482
# ==>>> epoch: 3, batch index: 600, train loss: 0.041105
# ==>>> epoch: 3, batch index: 100, test loss: 0.032701, acc: 0.984
# ==>>> epoch: 4, batch index: 100, train loss: 0.025007
# ==>>> epoch: 4, batch index: 200, train loss: 0.031138
# ==>>> epoch: 4, batch index: 300, train loss: 0.029181
# ==>>> epoch: 4, batch index: 400, train loss: 0.041623
# ==>>> epoch: 4, batch index: 500, train loss: 0.028719
# ==>>> epoch: 4, batch index: 600, train loss: 0.034751
# ==>>> epoch: 4, batch index: 100, test loss: 0.026534, acc: 0.989
# ==>>> epoch: 5, batch index: 100, train loss: 0.026326
# ==>>> epoch: 5, batch index: 200, train loss: 0.024292
# ==>>> epoch: 5, batch index: 300, train loss: 0.035105
# ==>>> epoch: 5, batch index: 400, train loss: 0.033674
# ==>>> epoch: 5, batch index: 500, train loss: 0.028428
# ==>>> epoch: 5, batch index: 600, train loss: 0.020940
# ==>>> epoch: 5, batch index: 100, test loss: 0.019209, acc: 0.990
# ==>>> epoch: 6, batch index: 100, train loss: 0.017562
# ==>>> epoch: 6, batch index: 200, train loss: 0.016280
# ==>>> epoch: 6, batch index: 300, train loss: 0.030013
# ==>>> epoch: 6, batch index: 400, train loss: 0.023610
# ==>>> epoch: 6, batch index: 500, train loss: 0.025240
# ==>>> epoch: 6, batch index: 600, train loss: 0.030230
# ==>>> epoch: 6, batch index: 100, test loss: 0.014151, acc: 0.991
# ==>>> epoch: 7, batch index: 100, train loss: 0.016950
# ==>>> epoch: 7, batch index: 200, train loss: 0.021529
# ==>>> epoch: 7, batch index: 300, train loss: 0.020419
# ==>>> epoch: 7, batch index: 400, train loss: 0.018334
# ==>>> epoch: 7, batch index: 500, train loss: 0.027355
# ==>>> epoch: 7, batch index: 600, train loss: 0.023905
# ==>>> epoch: 7, batch index: 100, test loss: 0.011637, acc: 0.991
# ==>>> epoch: 8, batch index: 100, train loss: 0.015936
# ==>>> epoch: 8, batch index: 200, train loss: 0.009924
# ==>>> epoch: 8, batch index: 300, train loss: 0.013939
# ==>>> epoch: 8, batch index: 400, train loss: 0.016949
# ==>>> epoch: 8, batch index: 500, train loss: 0.017128
# ==>>> epoch: 8, batch index: 600, train loss: 0.022517
# ==>>> epoch: 8, batch index: 100, test loss: 0.013929, acc: 0.991
# ==>>> epoch: 9, batch index: 100, train loss: 0.010328
# ==>>> epoch: 9, batch index: 200, train loss: 0.010710
# ==>>> epoch: 9, batch index: 300, train loss: 0.010386
# ==>>> epoch: 9, batch index: 400, train loss: 0.013894
# ==>>> epoch: 9, batch index: 500, train loss: 0.010061
# ==>>> epoch: 9, batch index: 600, train loss: 0.020267
# ==>>> epoch: 9, batch index: 100, test loss: 0.022010, acc: 0.990

# %%
the_model = LeNet()
the_model.load_state_dict(torch.load("LeNet"))  #读取网络参数
